# %% [markdown]
# ## Experimentos

# %%
from math import e, exp, log

print(pow(e, 1) == exp(log(e)))
print(pow(2, 2) == exp(2 * log(2)))
print(log(e, e) == exp(0))
# Out:
# True
# True
# True

# %%
import platform

print(platform.platform(aliased = False, terse = False))
print(platform.machine())
print(platform.processor())
print(platform.version())
# Out:
# Windows-11-10.0.26200-SP0
# AMD64
# Intel64 Family 6 Model 140 Stepping 1, GenuineIntel
# 10.0.26200

# %%
#pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/10.6 MB 8.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/10.6 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 14.3 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygame

run = True
width = 400
height = 100
pygame.init()
screen = pygame.display.set_mode((width, height))
font = pygame.font.SysFont(None, 48)
text = font.render("Welcome to pygame", True, (255, 255, 255))
screen.blit(text, ((width - text.get_width()) // 2, (height - text.get_height()) // 2))
pygame.display.flip()
while run:
  for event in pygame.event.get():
   if event.type == pygame.QUIT\
   or event.type == pygame.MOUSEBUTTONUP\
   or event.type == pygame.KEYUP:
    run = False
# Out:
# c:\Users\emili\anaconda3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#      10 screen.blit(text, ((width - text.get_width()) // 2, (height - text.get_height()) // 2))
#      11 pygame.display.flip()
# ---> 12 while run:
#      13   for event in pygame.event.get():
#      14    if event.type == pygame.QUIT\
#      15    or event.type == pygame.MOUSEBUTTONUP\
# ...

# %%
print("This is incredible. This is crazy!".replace("is", "are", 1))
# Out:
# Thare is incredible. This is crazy!

# %%
print("cisco.com".rstrip("com"))
# Out:
# cisco.

# %% [markdown]
# ## LAB

# %%
def mysplit(strng):
    lst = []
    strng = strng.lstrip()

    if len(strng) != 0:
        word = ""
        count = 0

        for char in strng:
            if char.isspace() == False and count != (len(strng) - 1):
                word += char
                count += 1
            elif (count + 1) == len(strng):
                word += char
                lst.append(word)
            else:
                lst.append(word)
                word = ""
                count += 1
        return lst
    return lst


print(mysplit("To be or not to be, that is the question"))
print(mysplit("To be or not to be,that is the question"))
print(mysplit("   "))
print(mysplit(" abc "))
print(mysplit(""))
# Out:
# ['To', 'be', 'or', 'not', 'to', 'be,', 'that', 'is', 'the', 'question']
# ['To', 'be', 'or', 'not', 'to', 'be,that', 'is', 'the', 'question']
# []
# ['abc ']
# []

# %%
ord("2")
# Out:
# 50

# %%
s1 = 'Where are the snows of yesteryear?'
s2 = s1.split()
s3 = sorted(s2)
print(s3)
# Out:
# ['Where', 'are', 'of', 'snows', 'the', 'yesteryear?']

# %% [markdown]
# ## LAB

# %%
def display_board(lst):
    
    for i in range(5):
        aux = []
        for n in range(len(lst)):
            aux += (digits[lst[n]][i] + [" "])
        print(" ".join(aux))

def num_to_str(num):
    global nums_text
    for dgt in num:
        if dgt == ".":
            nums_text.append("point")
        elif int(dgt) == 0:
            nums_text.append("zero")
        elif int(dgt) == 1:
            nums_text.append("one")
        elif int(dgt) == 2:
            nums_text.append("two")
        elif int(dgt) == 3:
            nums_text.append("three")
        elif int(dgt) == 4:
            nums_text.append("four")
        elif int(dgt) == 5:
            nums_text.append("five")
        elif int(dgt) == 6:
            nums_text.append("six")
        elif int(dgt) == 7:
            nums_text.append("seven")
        elif int(dgt) == 8:
            nums_text.append("eight")
        elif int(dgt) == 9:
            nums_text.append("nine")
    return

# Números precargados
zero = [["#", "#", "#"], ["#", " ", "#"], ["#", " ", "#"], ["#", " ", "#"], ["#", "#", "#"]]
one = [["#", "#", " "], [" ", "#", " "], [" ", "#", " "], [" ", "#", " "], ["#", "#", "#"]]
two = [["#", "#", "#"], [" ", " ", "#"], ["#", "#", "#"], ["#", " ", " "], ["#", "#", "#"]]
three = [["#", "#", "#"], [" ", " ", "#"], ["#", "#", "#"], [" ", " ", "#"], ["#", "#", "#"]]
four = [["#", " ", "#"], ["#", " ", "#"], ["#", "#", "#"], [" ", " ", "#"], [" ", " ", "#"]]
five = [["#", "#", "#"], ["#", " ", " "], ["#", "#", "#"], [" ", " ", "#"], ["#", "#", "#"]]
six = [["#", "#", "#"], ["#", " ", " "], ["#", "#", "#"], ["#", " ", "#"], ["#", "#", "#"]]
seven = [["#", "#", "#"], [" ", " ", "#"], [" ", "#", "#"], [" ", " ", "#"], [" ", " ", "#"]]
eight = [["#", "#", "#"], ["#", " ", "#"], ["#", "#", "#"], ["#", " ", "#"], ["#", "#", "#"]]
nine = [["#", "#", "#"], ["#", " ", "#"], ["#", "#", "#"], [" ", " ", "#"], [" ", " ", "#"]]
point = [["", " ", ""], ["", " ", ""], ["", " ", ""], ["", " ", ""], ["", "#", ""]]

# Diccionario que me conecte strings con el nombre de variables
digits = {"zero": zero, "one": one, "two": two, "three": three, "four": four, "five": five, "six": six, "seven": seven, "eight": eight, "nine": nine, "point": point}
nums_text = []
num = input("Ingresa el número que quieres visualizar:\n")
num_to_str(num)
display_board(nums_text)
# Out:
# #   #         #   #   #   #
# #   #         #   #   #   #
# # # #         # # #   # # #
#     #             #       #
#     #    #        #       #

# %% [markdown]
# ## Ejemplos

# %%
# Caesar cipher.
text = input("Enter your message: ")
cipher = ''
for char in text:
    if not char.isalpha():
        continue
    char = char.upper()
    code = ord(char) + 1
    if code > ord('Z'):
        code = ord('A')
    cipher += chr(code)

print(cipher)
# Out:
# IPMB

# %%
# Caesar cipher - decrypting a message.
cipher = input('Enter your cryptogram: ')
text = ''
for char in cipher:
    if not char.isalpha():
        continue
    char = char.upper()
    code = ord(char) - 1
    if code < ord('A'):
        code = ord('Z')
    text += chr(code)

print(text)
# Out:
# HOLA

# %%
# Numbers Processor.

line = input("Enter a line of numbers - separate them with spaces: ")
strings = line.split()
total = 0
try:
    for substr in strings:
        total += float(substr)
    print("The total is:", total)
except:
    print(substr, "is not a number.")
# Out:
# The total is: 0

# %%
# IBAN Validator.

iban = input("Enter IBAN, please: ")
iban = iban.replace(' ','')

if not iban.isalnum():
    print("You have entered invalid characters.")
elif len(iban) < 15:
    print("IBAN entered is too short.")
elif len(iban) > 31:
    print("IBAN entered is too long.")
else:
    iban = (iban[4:] + iban[0:4]).upper()
    iban2 = ''
    for ch in iban:
        if ch.isdigit():
            iban2 += ch
        else:
            iban2 += str(10 + ord(ch) - ord('A'))
    iban = int(iban2)
    if iban % 97 == 1:
        print("IBAN entered is valid.")
    else:
        print("IBAN entered is invalid.")

# %% [markdown]
# ## LAB

# %%
# Caesar cipher mejorado.
text = input("Enter your message: ")

while True:
    shift = input("¿Por cuántas unidades quieres desfasar el mensaje? Elige de 1 al 25.")
    try:
        shift = int(shift)
        if 0 < shift < 26:
            break
        elif shift == 0:
            print("No hay cifrado. Intentálo de nuevo.")
        else:
            print("Ingresa un número válido.")
    except:
        print("Ingresa un número, no un caracter.")

cipher = ''
for char in text:
    if not char.isalpha():
        cipher += char
        continue
    code = ord(char) + shift

    if char.islower():
        if code > ord('z'):
            code = ord('a') + (shift - (ord("z") - ord(char)) - 1)
    else:
        if code > ord('Z'):
            code = ord('A') + (shift - (ord("Z") - ord(char)) - 1)
    cipher += chr(code)

print(cipher)
# Out:
# Ingresa un número, no un caracter.
# Ingresa un número, no un caracter.
# Ingresa un número válido.
# ipmb

# %% [markdown]
# ## LAB

# %%
# Palíndromos
import math as m
print("PALÍNDROMOS")
text = input("Ingresa la palabra o frase que quieras revisar: ")
text_lwr = text.lower()
text_no_spaces = text_lwr.replace(" ", "")
# Hacemos una lista de los caracteres (no la vamos a modificar)
lst_o = []
for char in text_no_spaces:
    lst_o.append(char)
# Hacemos otra lista igual (esta sí la modificaremos)
lst = []
for char in text_no_spaces:
    lst.append(char)


# Revertimos la palabra
if len(lst) == 0:
    print(f"'{text}' NO es un palíndromo.")
elif len(lst) % 2 == 0:
    for i in range(int(len(lst) / 2)):
        lst[0 + i], lst[-1 - i] = lst[-1 - i], lst[0 + i]
    if lst == lst_o:
        print(f"'{text}' SÍ es un palíndromo.")
    else:
        print(f"'{text}' NO es un palíndromo.")
else:
    for i in range(m.floor(len(lst) / 2)):
        lst[0 + i], lst[-1 - i] = lst[-1 - i], lst[0 + i]
    if lst == lst_o:
        print(f"'{text}' SÍ es un palíndromo.")
    else:
        print(f"'{text}' NO es un palíndromo.")
# Out:
# PALÍNDROMOS
# '' NO es un palíndromo.

# %%
# Anagramas
text1 = input("Ingresa la primera palabra o frase: ")
text1.lower()
text2 = input("Ingresa la segunda palabra o frase: ")
text2.lower()
lst1 = []
for char in text1:
    lst1.append(char)
#print(lst1)
lst2 = []
for char in text2:
    lst2.append(char)
#print(lst2)


if lst1 == lst2:
    print("Los textos son anagramas.")
else:
    print("No son anagramas.")
# Out:
# ['m', 'o', 'd', 'e', 'r', 'n']
# ['n', 'o', 'r', 'm', 'a', 'n']
# No son anagramas.

# %%
# The Digit of Life
string = input("Ingresa tu fecha de nacimiento en formato YYYYMMDD: ")
suma = 0

while len(string) != 1:
    suma = 0
    for char in string:
        dgt = int(char)
        suma += dgt
    string = str(suma)

print(f"El dígito de la vida para la fecha proporcionada es {suma}.")
# Out:
# El dígito de la vida para la fecha proporcionada es 5.

# %%
# Encontrar una palabra
text1 = input("Ingresa el texto que quieres buscar: ")
text2 = input("Ingresa el text donde quieres buscar tu palabra: ")
indexes = []
count = 0
i = 0

for char in text1:
    i = text2.find(char, i)
    indexes.append(i)
#print(indexes)

for x in range(len(indexes) - 1):
    if -1 in indexes:
        print(f"{text1} no está en el texto.")
        break
    elif indexes[x] < indexes[x + 1]:
        count += 1
        #print(count)
        continue
    else:
        print(f"{text1} no está en el texto.")
        break

if count == len(indexes) - 1:
    print(f"{text1} sí está en el texto.")
# Out:
# donut no está en el texto.

# %% [markdown]
# ## LAB

# %%
# Sudoku
def row_suma(brd):
    # Checar que las filas sumen 45 (eso suman los números del 1 al 9)
    for elem in brd:
        suma = 0
        for char in elem:
            dgt = int(char)
            suma += dgt
        
        if suma != 45:
            return False
        else:
            return True

def col_suma(brd):
    # Checar que las columnas sumen 45
    
    for i in range(9):
        suma = 0
        for elem in brd:
            dgt = int(elem[i])
            suma += dgt
        
        if suma != 45:
            return False
        else:
            return True

def box_suma(brd):
    # Sumamos los valores de cada cuadrante.
    suma1 = 0
    suma2 = 0
    suma3 = 0
    suma4 = 0
    suma5 = 0
    suma6 = 0
    suma7 = 0
    suma8 = 0
    suma9 = 0
    # Cuadrante 1
    for c in range(3):
        for r in range(3):
            dgt = int(brd[r][c])
            suma1 += dgt
    #print(suma1)

    # Cuadrante 2
    for c in range(3, 6):
        for r in range(3):
            dgt = int(brd[r][c])
            suma2 += dgt
    #print(suma2)

    # Cuadrante 3
    for c in range(6, 9):
        for r in range(3):
            dgt = int(brd[r][c])
            suma3 += dgt
    #print(suma3)

    # Cuadrante 4
    for c in range(3):
        for r in range(3, 6):
            dgt = int(brd[r][c])
            suma4 += dgt
    #print(suma4)

    # Cuadrante 5
    for c in range(3, 6):
        for r in range(3, 6):
            dgt = int(brd[r][c])
            suma5 += dgt
    #print(suma5)

    # Cuadrante 6
    for c in range(6, 9):
        for r in range(3, 6):
            dgt = int(brd[r][c])
            suma6 += dgt
    #print(suma6)

    # Cuadrante 7
    for c in range(3):
        for r in range(6, 9):
            dgt = int(brd[r][c])
            suma7 += dgt
    #print(suma7)

    # Cuadrante 8
    for c in range(3, 6):
        for r in range(3, 6):
            dgt = int(brd[r][c])
            suma8 += dgt
    #print(suma8)

    # Cuadrante 9
    for c in range(6, 9):
        for r in range(3, 6):
            dgt = int(brd[r][c])
            suma9 += dgt
    #print(suma9)

    total = suma1 + suma2 + suma3 + suma4 + suma5 + suma6 + suma7 + suma8 + suma9
    if total == 405:
        return True
    else:
        return False



board = []
for i in range(9):
    txt = input(f"Ingresa los números de la fila número {i}: ")
    board.append(txt)
print(board)

if row_suma(board) == col_suma(board) and col_suma(board) == box_suma(board):
    print("Sudoku válido.")
else:
    print("Sudoku no válido.")
# Out:
# ['295743861', '431865927', '876192543', '387459216', '612387495', '549216738', '763524189', '928671354', '154938672']
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# Sudoku válido.

# %% [markdown]
# ## LAB

# %%
def read_int(prompt, min, max):

    while True:
        try:
            prompt = int(prompt)
            assert min < prompt and prompt < max
            return prompt
        except ValueError:
            print("Error: input erróneo.")
            prompt = input("Intenta con otro número:")
        except AssertionError:
            print("Error: el número no está dentro del rango indicado.")
            prompt = input("Intenta con otro número:")

i = input("Enter a number from -10 to 10: ")
v = read_int(i, -10, 10)

print("The number is:", v)
# Out:
# Error: el número no está dentro del rango indicado.
# Error: input erróneo.
#  Inténtelo de nuevo:
# The number is: 8

# %%
class MiPrimeraClase:
    pass

mi_primer_objeto = MiPrimeraClase()

# %% [markdown]
# ## Implementación de Stacks, Procedural vs POO
#
# ### Procedural

# %%
stack = []

def push(value):
    stack.append(value)

def pop():
    val = stack[-1]
    del stack[-1]
    return val

push(3)
push(2)
push(1)

print(pop())
print(pop())
print(pop())
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### Obtjetiva (POO)

# %%
class Stack:
    def __init__(self):
        self.__stack_list = []
    
    def push(self, val):
        self.__stack_list.append(val)

    def pop(self):
        val = self.__stack_list[-1]
        del self.__stack_list[-1]
        return val

stack_object = Stack()

stack_object.push(3)
stack_object.push(2)
stack_object.push(1)

print(stack_object.pop())
print(stack_object.pop())
print(stack_object.pop())
# Out:
# 1
# 2
# 3

# %%
stack_object1 = Stack()
stack_object2 = Stack()

stack_object1.push(3)
stack_object2.push(stack_object1.pop())

print(stack_object2.pop())
# Out:
# 3

# %%
little_stack = Stack()
another_stack = Stack()
funny_stack = Stack()

little_stack.push(1)
another_stack.push(little_stack.pop() + 1)
funny_stack.push(another_stack.pop() - 2)

print(funny_stack.pop())
# Out:
# 0

# %% [markdown]
# Ahora queremos una nueva clase que sume los valores del stack. Como no queremos modificar el stack original, sino añadirle una funcionalidad, lo que hacemos es una subclase que tome la clase Stack como base, es decir, que herede sus objetos y propiedades (superclase) y sobre ellos creemos nuevas funcionalidades.

# %%
class AddingStack(Stack):
    def __init__(self):
        Stack.__init__(self)
        self.__sum = 0

    def push(self, val):
        self.__sum += val
        Stack.push(self, val)

    def pop(self):
        val = Stack.pop(self)
        self.__sum -= val
        return val
    
    def get_sum(self):
        return self.__sum
    
stack_object = AddingStack()

for i in range(5):
    stack_object.push(i)
print(stack_object.get_sum())

for i in range(5):
    print(stack_object.pop())
# Out:
# 10
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ## LAB - Counting Stack

# %%
class Stack:
    def __init__(self):
        self.__stk = []

    def push(self, val):
        self.__stk.append(val)

    def pop(self):
        val = self.__stk[-1]
        del self.__stk[-1]
        return val


class CountingStack(Stack):
    def __init__(self):
        Stack.__init__(self)
        self.__counter = 0

    def get_counter(self):
        return self.__counter

    def pop(self):
        val = Stack.pop(self)
        self.__counter += 1
        return val
	

stk = CountingStack()

for i in range(100):
    stk.push(i)
    stk.pop()
print(stk.get_counter())
# Out:
# 100

# %% [markdown]
# ## LAB - Queue aka FIFO

# %%
class QueueError(IndexError):
    pass
            

class Queue:
    def __init__(self):
        self.__lst = []

    def put(self, elem):
        self.__lst.append(elem)

    def get(self):
        val = self.__lst[0]
        del self.__lst[0]
        return val
    
class SuperQueue(Queue):
    def __innit__(self):
        Queue.__init__(self)

    def is_empty(self):
        if len(self.__lst) == 0:
            return True
        else:
            return False

    
que = SuperQueue()
que.put(1)
que.put("dog")
que.put(False)
try:
    for i in range(4):
        print(que.get())
except:
    print("Queue Error")
# Out:
# 1
# dog
# False
# Queue Error

# %% [markdown]
# ---

# %% [markdown]
# # POO - Propiedades
#
# ### Instance Variables

# %%
class ExampleClass:
    def __init__(self, val = 1):
        self.first = val

    def set_second(self, val):
        self.second = val


example_object_1 = ExampleClass()
example_object_2 = ExampleClass(2)

example_object_2.set_second(3)

example_object_3 = ExampleClass(4)
example_object_3.third = 5

print(example_object_1.__dict__)
print(example_object_2.__dict__)
print(example_object_3.__dict__)
# Out:
# {'first': 1}
# {'first': 2, 'second': 3}
# {'first': 4, 'third': 5}

# %%
class ExampleClass:
    def __init__(self, val = 1):
        self.__first = val

    def set_second(self, val = 2):
        self.__second = val


example_object_1 = ExampleClass()
example_object_2 = ExampleClass(2)

example_object_2.set_second(3)

example_object_3 = ExampleClass(4)
example_object_3.__third = 5


print(example_object_1.__dict__)
print(example_object_2.__dict__)
print(example_object_3.__dict__)
# Out:
# {'_ExampleClass__first': 1}
# {'_ExampleClass__first': 2, '_ExampleClass__second': 3}
# {'_ExampleClass__first': 4, '__third': 5}

# %% [markdown]
# ### Class Variables

# %%
class ExampleClass:
    counter = 0
    def __init__(self, val = 1):
        self.__first = val
        ExampleClass.counter += 1


example_object_1 = ExampleClass()
example_object_2 = ExampleClass(2)
example_object_3 = ExampleClass(4)

print(example_object_1.__dict__, example_object_1.counter)
print(example_object_2.__dict__, example_object_2.counter)
print(example_object_3.__dict__, example_object_3.counter)
# Out:
# {'_ExampleClass__first': 1} 3
# {'_ExampleClass__first': 2} 3
# {'_ExampleClass__first': 4} 3

# %%
class ExampleClass:
    __counter = 0
    def __init__(self, val = 1):
        self.__first = val
        ExampleClass.__counter += 1


example_object_1 = ExampleClass()
example_object_2 = ExampleClass(2)
example_object_3 = ExampleClass(4)

print(example_object_1.__dict__, example_object_1._ExampleClass__counter)
print(example_object_2.__dict__, example_object_2._ExampleClass__counter)
print(example_object_3.__dict__, example_object_3._ExampleClass__counter)
# Out:
# {'_ExampleClass__first': 1} 3
# {'_ExampleClass__first': 2} 3
# {'_ExampleClass__first': 4} 3

# %%
class ExampleClass:
    varia = 1
    def __init__(self, val):
        ExampleClass.varia = val


print(ExampleClass.__dict__)
example_object = ExampleClass(2)

print(ExampleClass.__dict__)
print(example_object.__dict__)
# Out:
# {'__module__': '__main__', '__firstlineno__': 1, 'varia': 1, '__init__': <function ExampleClass.__init__ at 0x0000013801977240>, '__static_attributes__': (), '__dict__': <attribute '__dict__' of 'ExampleClass' objects>, '__weakref__': <attribute '__weakref__' of 'ExampleClass' objects>, '__doc__': None}
# {'__module__': '__main__', '__firstlineno__': 1, 'varia': 2, '__init__': <function ExampleClass.__init__ at 0x0000013801977240>, '__static_attributes__': (), '__dict__': <attribute '__dict__' of 'ExampleClass' objects>, '__weakref__': <attribute '__weakref__' of 'ExampleClass' objects>, '__doc__': None}
# {}

# %% [markdown]
# ### Checar la existencia de un atributo

# %%
class ExampleClass:
    def __init__(self, val):
        if val % 2 != 0:
            self.a = 1
        else:
            self.b = 1


example_object = ExampleClass(1)

print(example_object.a)
print(example_object.b)
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 12
#       9 example_object = ExampleClass(1)
#      11 print(example_object.a)
# ---> 12 print(example_object.b)
#
# AttributeError: 'ExampleClass' object has no attribute 'b'

# %%
class ExampleClass:
    def __init__(self, val):
        if val % 2 != 0:
            self.a = 1
        else:
            self.b = 1


example_object = ExampleClass(1)
print(example_object.a)

try:
    print(example_object.b)
except AttributeError:
    pass
# Out:
# 1

# %%
class ExampleClass:
    def __init__(self, val):
        if val % 2 != 0:
            self.a = 1
        else:
            self.b = 1
 
 
example_object = ExampleClass(1)
print(example_object.a)
 
if hasattr(example_object, 'b'):
    print(example_object.b)
# Out:
# 1

# %%
class ExampleClass:
    attr = 1


print(hasattr(ExampleClass, 'attr'))
print(hasattr(ExampleClass, 'prop'))
# Out:
# True
# False

# %%
class ExampleClass:
    a = 1
    def __init__(self):
        self.b = 2
 
 
example_object = ExampleClass()
 
print(hasattr(example_object, 'b'))
print(hasattr(example_object, 'a'))
print(hasattr(ExampleClass, 'b'))
print(hasattr(ExampleClass, 'a'))
# Out:
# True
# True
# False
# True

# %% [markdown]
# ### Métodos

# %%
class Classy:
    varia = 1
    def __init__(self):
        self.var = 2

    def method(self):
        pass

    def __hidden(self):
        pass


obj = Classy()

print(obj.__dict__)
print(Classy.__dict__)
# Out:
# {'var': 2}
# {'__module__': '__main__', '__firstlineno__': 1, 'varia': 1, '__init__': <function Classy.__init__ at 0x0000013801EFEAC0>, 'method': <function Classy.method at 0x0000013801EFE700>, '_Classy__hidden': <function Classy.__hidden at 0x0000013801EFE5C0>, '__static_attributes__': ('var',), '__dict__': <attribute '__dict__' of 'Classy' objects>, '__weakref__': <attribute '__weakref__' of 'Classy' objects>, '__doc__': None}

# %%
class Classy:
    pass


print(Classy.__name__)
obj = Classy()
print(type(obj).__name__)
# Out:
# Classy
# Classy

# %%
class Classy:
    pass


print(Classy.__module__)
obj = Classy()
print(obj.__module__)
# Out:
# __main__
# __main__

# %%
class SuperOne:
    pass


class SuperTwo:
    pass


class Sub(SuperOne, SuperTwo):
    pass


def printBases(cls):
    print('( ', end='')

    for x in cls.__bases__:
        print(x.__name__, end=' ')
    print(')')


printBases(SuperOne)
printBases(SuperTwo)
printBases(Sub)
# Out:
# ( object )
# ( object )
# ( SuperOne SuperTwo )

# %%
class MyClass:
    pass


obj = MyClass()
obj.a = 1
obj.b = 2
obj.i = 3
obj.ireal = 3.5
obj.integer = 4
obj.z = 5


def incIntsI(obj):
    for name in obj.__dict__.keys():
        if name.startswith('i'):
            val = getattr(obj, name)
            if isinstance(val, int):
                setattr(obj, name, val + 1)


print(obj.__dict__)
incIntsI(obj)
print(obj.__dict__)
# Out:
# {'a': 1, 'b': 2, 'i': 3, 'ireal': 3.5, 'integer': 4, 'z': 5}
# {'a': 1, 'b': 2, 'i': 4, 'ireal': 3.5, 'integer': 5, 'z': 5}

# %% [markdown]
# ## LAB - The Timer Class

# %%
class Timer:
    def __init__(self, hours = 0, minutes = 0, seconds = 0):
        self.__h = hours
        self.__m = minutes
        self.__s = seconds

    def __str__(self):
        self.__str = f"{0 if self.__h < 10 else ""}{self.__h}:{0 if self.__m < 10 else ""}{self.__m}:{0 if self.__h < 10 else ""}{self.__s}"
        return self.__str

    def next_second(self):
        self.__s += 1
        if self.__s < 60:
            return
        self.__s = 0
        self.__m += 1
        if self.__m < 60:
            return
        self.__m = 0
        self.__h +=1
        if self.__h < 24:
            return
        self.__h = 0
        return

    def prev_second(self):
        if self.__s > 0:
            self.__s -= 1
            return
        self.__s = 59
        if self.__m > 0:
            self.__m -= 1
            return
        self.__m = 59
        if self.__h > 0:
            self.__h -=1
            return
        self.__h = 23
        return


timer = Timer(23, 59, 59)
print(timer)
timer.next_second()
print(timer)
timer.prev_second()
print(timer)
# Out:
# 23:59:59
# 00:00:00
# 23:59:59

# %% [markdown]
# ## LAB - Days of the Week

# %%
class WeekDayError(AssertionError):
    pass
	

class Weeker:
    __days = ["MON", "TUE", "WED", "THU", "FRI", "SAT", "SUN"]

    def __init__(self, day):
        self.__d = day.upper()
        if self.__d not in Weeker.__days:
            raise WeekDayError
        self.__i = Weeker.__days.index(self.__d) + 1 #Sumo 1 para que el índice de MON sea 1 y así sucesivam.

    def __str__(self):
        return f"{self.__d.capitalize()}"

    def add_days(self, n):
        if n % 7 != 0:
            m = (self.__i + n) % 7
            self.__d = Weeker.__days[m - 1] #Quito 1 para que vuelva a ser índice correcto de la lista
            return
        return

    def subtract_days(self, n):
        if n % 7 != 0:
            m = abs((self.__i + 1) - n) % 7 # Sumo 1 para que el índice de MON sea 1 y así sucesivam.
            m = -m
            self.__d = Weeker.__days[m - 1] #Quito 1 para que vuelva a ser índice correcto de la lista
            return
        return


try:
    weekday = Weeker('Mon')
    print(weekday)
    weekday.add_days(14)
    print(weekday)
    weekday.subtract_days(21)
    print(weekday)
    weekday = Weeker('Monday')
except WeekDayError:
    print("Sorry, I can't serve your request.")
# Out:
# Mon
# Mon
# Mon
# Sorry, I can't serve your request.

# %% [markdown]
# ## LAB - Points on a Plane

# %%
import math


class Point:
    def __init__(self, x=0.0, y=0.0):
        self.__x = x
        self.__y = y

    def getx(self):
        return self.__x

    def gety(self):
        return self.__y

    def distance_from_xy(self, x, y):
        diff_x = abs(self.__x - x)
        diff_y = abs(self.__y - y)
        return math.hypot(diff_x, diff_y)

    def distance_from_point(self, point):
        return self.distance_from_xy(point.getx(), point.gety())


point1 = Point(0, 0)
point2 = Point(1, 1)
print(point1.distance_from_point(point2))
print(point2.distance_from_xy(2, 0))
# Out:
# 1.4142135623730951
# 1.4142135623730951

# %% [markdown]
# ## LAB - Triangle

# %%
import math


class Point:
    def __init__(self, x=0.0, y=0.0):
        self.__x = x
        self.__y = y

    def getx(self):
        return self.__x

    def gety(self):
        return self.__y

    def distance_from_xy(self, x, y):
        diff_x = abs(self.__x - x)
        diff_y = abs(self.__y - y)
        return math.hypot(diff_x, diff_y)

    def distance_from_point(self, point):
        return self.distance_from_xy(point.getx(), point.gety())


class Triangle:
    def __init__(self, vertice1, vertice2, vertice3):
        self.__points = [vertice1, vertice2, vertice3]

    def perimeter(self):
        suma = 0
        for i in range(3):
            suma += self.__points[i].distance_from_point(self.__points[(i + 1) % 3])
        return suma


triangle = Triangle(Point(0, 0), Point(1, 0), Point(0, 1))
print(triangle.perimeter())
# Out:
# 3.414213562373095

# %% [markdown]
# ---

# %%
class Level1:
    variable_1 = 100
    def __init__(self):
        self.var_1 = 101

    def fun_1(self):
        return 102


class Level2(Level1):
    variable_2 = 200
    def __init__(self):
        super().__init__()
        self.var_2 = 201
    
    def fun_2(self):
        return 202


class Level3(Level2):
    variable_3 = 300
    def __init__(self):
        super().__init__()
        self.var_3 = 301

    def fun_3(self):
        return 302


obj = Level3()

print(obj.variable_1, obj.var_1, obj.fun_1())
print(obj.variable_2, obj.var_2, obj.fun_2())
print(obj.variable_3, obj.var_3, obj.fun_3())
# Out:
# 100 101 102
# 200 201 202
# 300 301 302

# %%
def print_exception_tree(thisclass, nest = 0):
    if nest > 1:
        print("   |" * (nest - 1), end="")
    if nest > 0:
        print("   +---", end="")

    print(thisclass.__name__)

    for subclass in thisclass.__subclasses__():
        print_exception_tree(subclass, nest + 1)


print_exception_tree(BaseException)
# Out:
# BaseException
#    +---BaseExceptionGroup
#    |   +---ExceptionGroup
#    +---Exception
#    |   +---ArithmeticError
#    |   |   +---FloatingPointError
#    |   |   +---OverflowError
#    |   |   +---ZeroDivisionError
#    |   |   |   +---DivisionByZero
#    |   |   |   +---DivisionUndefined
#    |   |   +---DecimalException
#    |   |   |   +---Clamped
#    |   |   |   +---Rounded
#    |   |   |   |   +---Underflow
#    |   |   |   |   +---Overflow
#    |   |   |   +---Inexact
#    |   |   |   |   +---Underflow
#    |   |   |   |   +---Overflow
#    |   |   |   +---Subnormal
#    |   |   |   |   +---Underflow
#    |   |   |   +---DivisionByZero
#    |   |   |   +---FloatOperation
#    |   |   |   +---InvalidOperation
#    |   |   |   |   +---ConversionSyntax
#    |   |   |   |   +---DivisionImpossible
#    |   |   |   |   +---DivisionUndefined
#    |   |   |   |   +---InvalidContext
#    |   +---AssertionError
#    |   |   +---WeekDayError
#    |   +---AttributeError
# ...

# %%
def print_args(args):
    lng = len(args)
    if lng == 0:
        print("")
    elif lng == 1:
        print(args[0])
    else:
        print(str(args))


try:
    raise Exception
except Exception as e:
    print(e, e.__str__(), sep=' : ' ,end=' : ')
    print_args(e.args)

try:
    raise Exception("my exception")
except Exception as e:
    print(e, e.__str__(), sep=' : ', end=' : ')
    print_args(e.args)

try:
    raise Exception("my", "exception")
except Exception as e:
    print(e, e.__str__(), sep=' : ', end=' : ')
    print_args(e.args)
# Out:
#  :  :
# my exception : my exception : my exception
# ('my', 'exception') : ('my', 'exception') : ('my', 'exception')

# %% [markdown]
# # Módulo 4

# %%
def powers_of_2(n):
    power = 1
    for i in range(n):
        yield power
        power *= 2


for v in powers_of_2(8):
    print(v)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128

# %%
def powers_of_2(n):
    power = 1
    for i in range(n):
        yield power
        power *= 2
 
 
t = [x for x in powers_of_2(5)]
print(t)
# Out:
# [1, 2, 4, 8, 16]

# %%
def powers_of_2(n):
    power = 1
    for i in range(n):
        yield power
        power *= 2
 
 
t = list(powers_of_2(3))
print(t)
# Out:
# [1, 2, 4]

# %%
any_list = [1, 2, 3, 4]
even_list = list(map(lambda n: n|1, any_list))
print(even_list)
# Out:
# [1, 3, 3, 5]

# %%
from os import strerror

try:
    counter = 0
    stream = open('text.txt', "rt")
    char = stream.read(1)
    while char != '':
        print(char, end='')
        counter += 1
        char = stream.read(1)
    stream.close()
    print("\n\nCharacters in file:", counter)
except IOError as e:
    print("I/O error occurred: ", strerror(e.errno))
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
#
# Characters in file: 131

# %%
from os import strerror

try:
    counter = 0
    stream = open('text.txt', "rt")
    content = stream.read()
    for char in content:
        print(char, end='')
        counter += 1
    stream.close()
    print("\n\nCharacters in file:", counter)
except IOError as e:
    print("I/O error occurred: ", strerr(e.errno))
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
#
# Characters in file: 131

# %%
from os import strerror

try:
    character_counter = line_counter = 0
    stream = open('text.txt', 'rt')
    line = stream.readline()
    while line != '':
        line_counter += 1
        for char in line:
            print(char, end='')
            character_counter += 1
        line = stream.readline()
    stream.close()
    print("\n\nCharacters in file:", character_counter)
    print("Lines in file:     ", line_counter)
except IOError as e:
    print("I/O error occurred:", strerror(e.errno))
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
#
# Characters in file: 131
# Lines in file:      4

# %%
stream = open("text.txt")
print(stream.readlines(20))
print(stream.readlines(40))
print(stream.readlines(80))
print(stream.readlines(160))
stream.close()
# Out:
# ['Beautiful is better than ugly.\n']
# ['Explicit is better than implicit.\n', 'Simple is better than complex.\n']
# ['Complex is better than complicated.']
# []

# %%
from os import strerror

try:
    ccnt = lcnt = 0
    s = open('text.txt', 'rt')
    lines = s.readlines(20)
    while len(lines) != 0:
        for line in lines:
            lcnt += 1
            for ch in line:
                print(ch, end='')
                ccnt += 1
        lines = s.readlines(10)
    s.close()
    print("\n\nCharacters in file:", ccnt)
    print("Lines in file:     ", lcnt)
except IOError as e:
    print("I/O error occurred:", strerror(e.errno))
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
#
# Characters in file: 131
# Lines in file:      4

# %%
from os import strerror

try:
	ccnt = lcnt = 0
	for line in open('text.txt', 'rt'):
		lcnt += 1
		for ch in line:
			print(ch, end='')
			ccnt += 1
	print("\n\nCharacters in file:", ccnt)
	print("Lines in file:     ", lcnt)
except IOError as e:
	print("I/O error occurred: ", strerror(e.errno))
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
#
# Characters in file: 131
# Lines in file:      4

# %%
from os import strerror

try:
	file = open('newtext.txt', 'wt') # A new file (newtext.txt) is created.
	for i in range(10):
		s = "line #" + str(i+1) + "\n"
		for char in s:
			file.write(char)
	file.close()
except IOError as e:
	print("I/O error occurred: ", strerror(e.errno))

# %%
from os import strerror

try:
    file = open('newtext.txt', 'wt')
    for i in range(10):
        file.write("line #" + str(i+1) + "\n")
    file.close()
except IOError as e:
    print("I/O error occurred: ", strerror(e.errno))

# %%
data = bytearray(10)

for i in range(len(data)):
    data[i] = 10 - i

for b in data:
    print(hex(b))
# Out:
# 0xa
# 0x9
# 0x8
# 0x7
# 0x6
# 0x5
# 0x4
# 0x3
# 0x2
# 0x1

# %%
from os import strerror

data = bytearray(10)

for i in range(len(data)):
    data[i] = 10 + i

try:
    bf = open('file.bin', 'wb')
    bf.write(data)
    bf.close()
    for b in data:
        print(hex(b))
except IOError as e:
    print("I/O error occurred:", strerror(e.errno))
# Out:
# 0xa
# 0xb
# 0xc
# 0xd
# 0xe
# 0xf
# 0x10
# 0x11
# 0x12
# 0x13

# %%
from os import strerror

data = bytearray(10)

try:
    binary_file = open('file.bin', 'rb')
    binary_file.readinto(data)
    binary_file.close()

    for b in data:
        print(hex(b), end=' ')
except IOError as e:
    print("I/O error occurred:", strerror(e.errno))
# Out:
# 0xa 0xb 0xc 0xd 0xe 0xf 0x10 0x11 0x12 0x13

# %% [markdown]
# ## LAB - Character Frequency Histogram

# %%
from os import strerror
hist = {}

try:
    src = input("Escribe el nombre del archivo .txt que quieras analizar: ")
    stream = open(src, "rt")
    text = stream.read()
    for char in text:
        hist[char.lower()] = 0
    #print(hist)
    for char in text:
        hist[char.lower()] += 1
    #print(hist)
    stream.close()

    for key in hist:
        print(f"{key} -> {hist[key]}")
except IOError as e:
    print("I/O error: ", strerror(e.errno))
# Out:
# a -> 3
# b -> 3
# c -> 3

# %% [markdown]
# ## LAB - Sorted Character Frecuency Program

# %%
from os import strerror
hist = {}

try:
    src = input("Escribe el nombre del archivo .txt que quieras analizar: ")
    stream = open(src, "rt")
    text = stream.read()
    for char in text:
        hist[char.lower()] = 0
    for char in text:
        hist[char.lower()] += 1
    stream.close()

    stream = open(src[:-3] + "hist", "wt")
    h_sorted = dict(sorted(hist.items(), key=lambda x: x[1], reverse=True))
    for key in h_sorted:
        print(f"{key} -> {h_sorted[key]}")
        stream.write(f"{key} -> {h_sorted[key]}\n")
    stream.close()

except IOError as e:
    print("I/O error: ", strerror(e.errno))
# Out:
# a -> 3
# b -> 2
# c -> 1

# %% [markdown]
# ## LAB - Evaluating Student's Results

# %%
try:
    src = input("Escribe el nombre del archivo .txt con las calificaciones: ")
    stream = open(src, "rt")
    line = stream.readline()
    calif = {}
    while line != "":
        #print(f"#{line}")
        lst = line.split()
        #print(lst)
        calif[lst[0] + " " + lst[1]] = 0.0
        #print(calif)
        line = stream.readline()
    stream.close()

    stream = open(src, "rt")
    line = stream.readline()
    #print("---------------------------------")
    while line != "":
        #print(f"#{line}")
        lst2 = line.split()
        #print(lst2)
        calif[lst2[0] + " " + lst2[1]] += float(lst2[2])
        line = stream.readline()
    stream.close()
    for key in calif:
            print(f"{key}:   {calif[key]}")

except IOError as e:
    print("I/O error: ", strerror(e.errno))
# Out:
# John Smith:   7.0
# Anna Boleyn:   15.5
# Andrew Cox:   1.5

# %% [markdown]
# ---

# %%
import os
import platform
print(platform.uname())
print(os.name)
# Out:
# uname_result(system='Windows', node='Emartlion', release='11', version='10.0.26200', machine='AMD64')
# nt

# %% [markdown]
# ## LAB - The `os` module

# %%
import os

class DirectorySearcher:
    def find(self, path, dir):
        try:
            os.chdir(path)
        except OSError:
            # Doesn't process a file that isn't a directory.
            return

        current_dir = os.getcwd()
        for entry in os.listdir("."):
            if entry == dir:
                print(os.getcwd() + "/" + dir)
            self.find(current_dir + "/" + entry, dir)


directory_searcher = DirectorySearcher()
directory_searcher.find("./tree", "python")

# %% [markdown]
# ---

# %%
from datetime import date

today = date.today()

print("Today:", today)
print("Year:", today.year)
print("Month:", today.month)
print("Day:", today.day)
# Out:
# Today: 2026-02-25
# Year: 2026
# Month: 2
# Day: 25

# %%
from datetime import date
import time

timestamp = time.time()
print("Timestamp:", timestamp)

d = date.fromtimestamp(timestamp)
print("Date:", d)
# Out:
# Timestamp: 1772076275.6259735
# Date: 2026-02-25

# %%
from datetime import date

d = date(1991, 2, 5)
print(d)

d = d.replace(year=1992, month=1, day=16)
print(d)
# Out:
# 1991-02-05
# 1992-01-16

# %%
from datetime import date

d = date(2019, 11, 4)
print(d.weekday()) # 0 es Lunes, 6 es Domingo
 
d = date(2019, 11, 4)
print(d.isoweekday()) #1 es Lunes, 7 es Domingo
# Out:
# 0
# 1

# %%
from datetime import time

t = time(14, 53, 20, 1)

print("Time:", t)
print("Hour:", t.hour)
print("Minute:", t.minute)
print("Second:", t.second)
print("Microsecond:", t.microsecond)
# Out:
# Time: 14:53:20.000001
# Hour: 14
# Minute: 53
# Second: 20
# Microsecond: 1

# %%
import time

class Student:
    def take_nap(self, seconds):
        print("I'm very tired. I have to take a nap. See you later.")
        time.sleep(seconds)
        print("I slept well! I feel great!")

student = Student()
student.take_nap(5)
# Out:
# I'm very tired. I have to take a nap. See you later.
# I slept well! I feel great!

# %%
import time

timestamp = 1572879180
print(time.ctime(timestamp))
print(time.ctime())
# Out:
# Mon Nov  4 08:53:00 2019
# Thu Feb 26 15:21:58 2026

# %% [markdown]
# ## LAB - The `datetime` and `time` modules

# %%
from datetime import datetime

date = datetime(2020, 11, 4, 14, 53)
print(date.strftime("%Y/%m/%d %H:%M:%S"))
print(date.strftime("%Y/%B/%d %H:%M:%S %p"))
print(date.strftime("%a, %Y %b %d"))
print(date.strftime("%A, %Y %B %d"))
print(f"Weekday: {date.strftime("%w")}")
print(f"Day of the Year: {date.strftime("%j")}")
print(f"Week Number of the Year: {date.strftime("%U")}")
# Out:
# 2020/11/04 14:53:00
# 2020/November/04 14:53:00 PM
# Wed, 2020 Nov 04
# Wednesday, 2020 November 04
# Weekday: 3
# Day of the Year: 309
# Week Number of the Year: 44

# %% [markdown]
# ---
#
# ## LAB - The calendar Module

# %%
import calendar

class MyCalendar(calendar.Calendar):
    def __init__(self, firstweekday = 0):
        super().__init__(firstweekday)

    def count_weekday_in_year(self, year, weekday):
        self.c = calendar.Calendar()
        self.count = 0

        for m in range(1, 13):
            for i in self.c.monthdays2calendar(year,m):
                #print(i)
                lst = list(map(lambda x: 1 if x[0] != 0 and x[1] == weekday else 0, i))
                self.count += sum(lst)
        print(self.count)

cal = MyCalendar()
cal.count_weekday_in_year(2000, 6)
# Out:
# 53

# %%
my_tuple = (0, 1, 2, 3, 4, 5, 6)
foo = list(filter(lambda x: x - 0 and x - 1, my_tuple))
print(foo)
# Out:
# [2, 3, 4, 5, 6]

# %%
def fun(n):
    s = '+'
    for i in range(n):
        s += s
        yield s


for x in fun(2):
    print(x, end='');
# Out:
# ++++++

# %%
def o(p):
    def q():
        return '*' * p
    return q


r = o(1)
s = o(2)
print(r() + s())
# Out:
# ***

# %%
import calendar

c = calendar.Calendar()

for weekday in c.iterweekdays():
    print(weekday, end=" ")
# Out:
# 0 1 2 3 4 5 6

# %%
class A:
    A = 1
    def __init__(self):
        self.a = 0


print(hasattr(A, 'a'))
# Out:
# False

# %%
def my_fun(n):
    s = '+'
    for i in range(n):
        s += s
        yield s


for x in my_fun(2):
    print(x, end='')
# Out:
# ++++++

# %%
class I:
    def __init__(self):
        self.s = 'abc'
        self.i = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.i == len(self.s):
            raise StopIteration
        v = self.s[self.i]
        self.i += 1
        return v


for x in I():
    print(x, end='')
# Out:
# abc

# %%
import calendar

calendar.setfirstweekday(calendar.SUNDAY)
print(calendar.weekheader(3))
# Out:
# Sun Mon Tue Wed Thu Fri Sat
