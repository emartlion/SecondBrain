# %% [markdown]
# # Experimentos Básicos con NumPy
#
# ## Arrays

# %%
import numpy as np

# %% [markdown]
# Una vez importada la librería, la usamos.

# %%
altura_lista = [1.4, 1.65, 1.89]
peso_lista = [52.2, 65.8, 80]

# %%
altura_lista / peso_lista
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 altura_lista / peso_lista
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
altura_array = np.array(altura_lista)
peso_array = np.array(peso_lista)

altura_array / peso_array
# Out:
# array([0.02681992, 0.02507599, 0.023625  ])
